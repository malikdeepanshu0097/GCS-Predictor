# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize']=(14,7)

# %%
print('''                                        ****** THE ULTIMATE PREDICTOR ******
    Choose the type of predictor:-
        1. Stock Market Predictor
        2. Global Currency Growth Predictor
        3. Gold Predictor
    ''')        
choice=int(input('Enter your choice : '))

if choice==1:
    print('''                                     ****** THE STOCK MARKET PREDICTOR******
        Choose the type of regression:-
            1. Predict Using Linear Regression
            2. Predict Using Advanced Regression
        ''')
    data = pd.read_csv('all_stocks_5yr.csv')
    #print(data.head())
    #data.shape

    #to remove unwanted columns from dataframe data
    data.drop('high',axis=1,inplace=True)
    data.drop('date',axis=1,inplace=True)
    data.drop('low',axis=1,inplace=True)
    data.drop('Name',axis=1,inplace=True)


    #print(data.head())


    #plot of stocks only

    a=data.head(500)#for only taking 1000 entries from dataframe data
    x=a.index
    y=a['close']
    #mean
    m=np.mean(y)


    plt.plot(x,y)#this is the plot between index and closing price
    plt.xlabel('Trading Days')
    plt.ylabel('Closing Price (USD)')
    plt.title('GOOGLE TRADING')
    plt.show()
    
    a=int(input('Enter your choice : '))
    if a==1:    
    
        #polyfit for linear regression
        p1=np.polyfit(x,y,1)
        #p1

        plt.plot(x,y)
        plt.plot(x,np.polyval(p1,x),'r-')
        plt.xlabel('Trading Days')
        plt.ylabel('Closing Price (USD)')
        plt.title('GOOGLE TRADING VS PREDICTION')
        plt.show()
        w=np.polyval(p1,x)
        #r^2 value for this curve
        y_sub_m=[]
        for i in y:
            j=pow((i-m),2)
            y_sub_m.append(j)
        w_sub_m=[]
        for i in w:
            j=pow((i-m),2)
            w_sub_m.append(j)
        r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
        print('Coefficient of determination(R-squared value) : ',r_sq)
        print('Predicted closing price(USD) is : ',w[499])
    elif a==2:
        #polyfit for advanced regression
        p1=np.polyfit(x,y,17)
        #p1

        plt.plot(x,y)
        plt.plot(x,np.polyval(p1,x),'r-')
        plt.xlabel('Trading Days')
        plt.ylabel('Closing Price (USD)')
        plt.title('GOOGLE TRADING VS PREDICTION')
        plt.show()
        w=np.polyval(p1,x)
        #r^2 value for this curve
        y_sub_m=[]
        for i in y:
            j=pow((i-m),2)
            y_sub_m.append(j)
        w_sub_m=[]
        for i in w:
            j=pow((i-m),2)
            w_sub_m.append(j)
        r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
        print('Coefficient of determination(R-squared value) : ',r_sq)
        print('Predicted closing price(USD) is : ',w[499])
    else:
        print('Wrong input')
        
if choice==2:
    print('''                                 ****** THE GLOBAL CURRENCY GROWTH PREDICTOR******
        The Global Currency Growth Predictor compares the cuurency of user's interest with the USD and predicts on the basis of it.
        Choose the currency of interest :-
            1. INR
            2. CNY
            3. AUD
            4. EUR''')
    b=int(input('Enter your choice'))
    if b==1:
        #INR
        print('''                                     ****** INR ******
            Choose the type of regression:-
                1. Predict Using Linear Regression
                2. Predict Using Advanced Regression''')
        
        data = pd.read_csv('Global economy since 2000.csv')
        
        data.drop(['Date','Change%_INR','Date_CNY','Change%_CNY','Date_AUD','Change%_AUD','Date_EUR','Change%_EUR'],axis=1,inplace=True)
        
        #plot for INR
        import matplotlib.pyplot as plt
        a=data.head(365)#for only taking 1000 entries from dataframe data
        x=a.index
        y=a['Price_INR']
        #mean of price_INR
        m=np.mean(y)
        
        plt.plot(x,y)
        plt.xlabel('Trading Days')
        plt.ylabel('INR')
        plt.title('INR GROWTH')
        plt.show()

        a=int(input('Enter your choice : '))
        
        if a==1:
            # linear regression
            
            p1=np.polyfit(x,y,1)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('INR')
            plt.title('INR GROWTH VS PREDICTION')
            plt.show()
            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value) : ',r_sq)
            print('Predicted INR is : ',w[0])
        elif a==2:
            #advanced regression
            
            p1=np.polyfit(x,y,17)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('INR')
            plt.title('INR GROWTH VS PREDICTION')
            plt.show()

            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value): ',r_sq)
            print('Predicted INR is : ',w[0])
        else:
            print('Wrong input')

    elif b==2:
        #INR
        print('''                                     ****** CNY ******
            Choose the type of regression:-
                1. Predict Using Linear Regression
                2. Predict Using Advanced Regression''')
        
        data = pd.read_csv('Global economy since 2000.csv')
        
        data.drop(['Date','Change%_INR','Date_CNY','Change%_CNY','Date_AUD','Change%_AUD','Date_EUR','Change%_EUR'],axis=1,inplace=True)
        
        #plot for INR
        import matplotlib.pyplot as plt
        a=data.head(365)#for only taking 1000 entries from dataframe data
        x=a.index
        y=a['Price_CNY']
        #mean of price_INR
        m=np.mean(y)
        
        plt.plot(x,y)
        plt.xlabel('Trading Days')
        plt.ylabel('CNY')
        plt.title('CNY GROWTH')
        plt.show()
            

        a=int(input('Enter your choice : '))
        
        if a==1:
            # linear regression
            
            p1=np.polyfit(x,y,1)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('CNY')
            plt.title('CNY GROWTH VS PREDICTION')
            plt.show()
            
            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value): ',r_sq)
            print('Predicted CNY is : ',w[0])
        elif a==2:
            #advanced regression
            
            p1=np.polyfit(x,y,17)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('CNY')
            plt.title('CNY GROWTH VS PREDICTION')
            plt.show()
            
            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value): ',r_sq)
            print('Predicted CNY is : ',w[0])
        else:
            print('Wrong input')

            
    elif b==3:
        print('''                                     ****** AUD ******
            Choose the type of regression:-
                1. Predict Using Linear Regression
                2. Predict Using Advanced Regression''')
        
        data = pd.read_csv('Global economy since 2000.csv')
        
        data.drop(['Date','Change%_INR','Date_CNY','Change%_CNY','Date_AUD','Change%_AUD','Date_EUR','Change%_EUR'],axis=1,inplace=True)
        
        #plot for INR
        import matplotlib.pyplot as plt
        a=data.head(365)#for only taking 1000 entries from dataframe data
        x=a.index
        y=a['Price_AUD']
        #mean of price_INR
        m=np.mean(y)
        
        plt.plot(x,y)
        plt.xlabel('Trading Days')
        plt.ylabel('AUD')
        plt.title('AUD GROWTH')
        plt.show()
            

        a=int(input('Enter your choice : '))
        
        if a==1:
            # linear regression
            
            p1=np.polyfit(x,y,1)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('AUD')
            plt.title('AUD GROWTH VS PREDICTION')
            plt.show()
            
            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value): ',r_sq)
            print('Predicted AUD is : ',w[0])
        elif a==2:
            #advanced regression
            
            p1=np.polyfit(x,y,17)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('AUD')
            plt.title('AUD GROWTH VS PREDICTION')
            plt.show()
            
            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value): ',r_sq)
            print('Predicted AUD is : ',w[0])
        else:
            print('Wrong input')

            
    elif b==4:
        print('''                                     ****** EUR ******
            Choose the type of regression:-
                1. Predict Using Linear Regression
                2. Predict Using Advanced Regression''')
        
        data = pd.read_csv('Global economy since 2000.csv')
        
        data.drop(['Date','Change%_INR','Date_CNY','Change%_CNY','Date_AUD','Change%_AUD','Date_EUR','Change%_EUR'],axis=1,inplace=True)
        
        #plot for INR
        import matplotlib.pyplot as plt
        a=data.head(365)#for only taking 1000 entries from dataframe data
        x=a.index
        y=a['Price_EUR']
        #mean of price_INR
        m=np.mean(y)
        
        plt.plot(x,y)
        plt.xlabel('Trading Days')
        plt.ylabel('EUR')
        plt.title('EUR GROWTH VS PREDICTION')
        plt.show()
            

        a=int(input('Enter your choice : '))
        
        if a==1:
            # linear regression
            
            p1=np.polyfit(x,y,1)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('EUR')
            plt.title('EUR GROWTH VS PREDICTION')
            plt.show()
            
            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value): ',r_sq)
            print('Predicted EUR is : ',w[0])
        elif a==2:
            #advanced regression
            
            p1=np.polyfit(x,y,17)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('EUR')
            plt.title('EUR GROWTH VS PREDICTION')
            plt.show()
            
            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value): ',r_sq)
            print('Predicted EUR is : ',w[0])
        else:
            print('Wrong input')
    else:
        print('Wrong input')

if choice==3:
    print('''                                        ****** THE GOLD PREDICTOR ******
        choose the type of standard :-
            1.SPX-Gold
            2.EUR/USD-Gold''')
    b=int(input('Enter your choice'))
    if b==1:
        print('''                                            ****** SPX-Gold******
            Choose the type of regression:-
                1. Predict Using Linear Regression
                2. Predict Using Advanced Regression''') 
        
        data=pd.read_csv('gld_price_data.csv')
        
        a=data.tail(1000)#for only taking 1000 entries from dataframe data
        x=range(0,1000)
        y=a['SPX']
        #mean of SPX
        m=np.mean(y)
        
        plt.plot(x,y)
        plt.xlabel('Trading Days')
        plt.ylabel('SPX')
        plt.title('SPX GROWTH')
        plt.show()
            
        
        a=int(input('Enter your choice : '))
        
        if a==1:
            # linear regression
            
            p1=np.polyfit(x,y,1)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('SPX')
            plt.title('SPX GROWTH VS PREDICTION')
            plt.show()
            
            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value): ',r_sq)
            print('Predicted SPX is : ',w[999])
            
        elif a==2:
            #advanced regression

            p1=np.polyfit(x,y,17)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('SPX')
            plt.title('SPX GROWTH VS PREDICTION')
            plt.show()

            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value): ',r_sq)
            print('Predicted SPX is : ',w[999])
        else:
            print('Wrong input')

        
    elif b==2:
        print('''                                            ****** EUR/USD-Gold ******
            Choose the type of regression:-
                1. Predict Using Linear Regression
                2. Predict Using Advanced Regression''') 
        
        data=pd.read_csv('gld_price_data.csv')
        
        a=data.tail(1000)#for only taking 1000 entries from dataframe data
        x=range(0,1000)
        y=a['EUR/USD']
        #mean of SPX
        m=np.mean(y)
        
        plt.plot(x,y)
        plt.xlabel('Trading Days')
        plt.ylabel('EUR/USD')
        plt.title('EUR/USD GROWTH')
        plt.show()
            
        
        a=int(input('Enter your choice : '))
        
        if a==1:
            # linear regression
            
            p1=np.polyfit(x,y,1)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('EUR/USD-Gold')
            plt.title('EUR/USD-Gold GROWTH VS PREDICTION')
            plt.show()
            
            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value): ',r_sq)
            print('Predicted EUR/USD-Gold iS : ',w[999])
            
        elif a==2:
            #advanced regression

            p1=np.polyfit(x,y,17)
            
            plt.plot(x,y)
            plt.plot(x,np.polyval(p1,x),'r-')
            plt.xlabel('Trading Days')
            plt.ylabel('EUR/USD-Gold')
            plt.title('EUR/USD-Gold GROWTH VS PREDICTION')
            plt.show()

            w=np.polyval(p1,x)
            #r^2 value for this curve
            y_sub_m=[]
            for i in y:
                j=pow((i-m),2)
                y_sub_m.append(j)
            w_sub_m=[]
            for i in w:
                j=pow((i-m),2)
                w_sub_m.append(j)
            r_sq=(np.sum(w_sub_m)/np.sum(y_sub_m))
            print('Coefficient of determination(R-squared value): ',r_sq)
            print('Predicted EUR/USD-Gold is : ',w[999])
        else:
            print('Wrong input')
    else:
        print('Wrong input')
# Out:
#                                         ****** THE ULTIMATE PREDICTOR ******
#     Choose the type of predictor:-
#         1. Stock Market Predictor
#         2. Global Currency Growth Predictor
#         3. Gold Predictor
#
# Enter your choice : 3
#                                         ****** THE GOLD PREDICTOR ******
#         choose the type of standard :-
#             1.SPX-Gold
#             2.EUR/USD-Gold
# Enter your choice2
#                                             ****** EUR/USD-Gold ******
#             Choose the type of regression:-
#                 1. Predict Using Linear Regression
#                 2. Predict Using Advanced Regression
# Enter your choice : 2
# Coefficient of determination(R-squared value):  0.9774184063052443
# Predicted EUR/USD-Gold is :  1.1969103094656692
